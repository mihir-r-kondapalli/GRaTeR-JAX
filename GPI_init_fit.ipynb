# %%
import GPI_init_fit as gpi
# Out:
# /home/blewis/GRaTeR-JAX/GPI_init_fit.py:86: SyntaxWarning: invalid escape sequence '\D'
#   axes[0].set_ylabel('$\Delta$RA (arcsec)',fontsize=14)
# /home/blewis/GRaTeR-JAX/GPI_init_fit.py:87: SyntaxWarning: invalid escape sequence '\D'
#   axes[0].set_xlabel('$\Delta$Dec (arcsec)',fontsize=14)
# /home/blewis/GRaTeR-JAX/GPI_init_fit.py:95: SyntaxWarning: invalid escape sequence '\D'
#   axes[1].set_xlabel('$\Delta$Dec (arcsec)',fontsize=14)
# /home/blewis/GRaTeR-JAX/GPI_init_fit.py:100: SyntaxWarning: invalid escape sequence '\D'
#   axes[2].set_xlabel('$\Delta$Dec (arcsec)',fontsize=14)
# /home/blewis/anaconda3/lib/python3.12/site-packages/cupyx/jit/_interface.py:173: FutureWarning: cupyx.jit.rawkernel is experimental. The interface can change in the future.
#   cupy._util.experimental('cupyx.jit.rawkernel')
# webbpsf_ext log messages of level WARN and above will be shown.
# webbpsf_ext log outputs will be directed to the screen.
# CuPy succesfully imported. Using GPU where applicable. Set use_gpu=False to override this functionality.

# %%
from astropy.stats import bayesian_info_criterion as bic
from astropy.stats import akaike_info_criterion as aic

def delta_criteria(ll1,np1,ll2,np2):
    d_bic = bic(ll1,np1,32400)-bic(ll2,np2,32400)
    d_aic = aic(ll1,np1,32400)-aic(ll2,np2,32400)
    print('$\Delta$BIC is',d_bic)
    print('$\Delta$AIC is',d_bic)
    print('If delta criteria are negative, the first model is preferred')

# %% [markdown]
# ## HR 4796A

# %%
model1, params1, ll1, knots1, angles1 = gpi.init_fit('hr4796a_H_pol',num_knots=9,save=True)
# Out:
#          Current function value: 79210.322329
#          Iterations: 98
#          Function evaluations: 3617
#          Gradient evaluations: 157
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 79210.32232884777
#         x: [ 4.876e+01 -1.904e+01 ...  3.461e-01 -1.029e-01]
#       nit: 98
#       jac: [ 1.607e+00 -1.669e+01 ...  1.446e+02 -2.908e+01]
#  hess_inv: [[ 2.184e+00  4.381e-02 ...  4.415e-03 -5.804e-03]
#             [ 4.381e-02  7.852e-02 ...  1.867e-04  3.964e-04]
#             ...
#             [ 4.415e-03  1.867e-04 ...  2.949e-05 -2.997e-05]
#             [-5.804e-03  3.964e-04 ... -2.997e-05  1.805e-04]]
#      nfev: 3617
#      njev: 157
# Disk Params: {'accuracy': 0.005, 'alpha_in': 48.75696492019186, 'alpha_out': -19.03755350286483, 'sma': 76.28436757623568, 'e': -0.1021240899373476, 'ksi0': 0.9427584932152895, 'gamma': 0.6928340993092313, 'beta': 8.635485363717347, 'amin': 0.0, 'dens_at_r0': 1.0, 'inclination': 76.63160739287062, 'position_angle': 26.66195587907528, 'x_center': 91.69507816705749, 'y_center': 90.61595281732919, 'halfNbSlices': 25, 'omega': -323.6065430154947}
# SPF Params: {'low_bound': Array(-0.97236992, dtype=float64), 'up_bound': Array(0.97236992, dtype=float64), 'num_knots': 9, 'knot_values': Array([ 4.30033334,  2.0329772 ,  1.73258065,  1.12365697,  1.        ,
#         0.65361038,  0.54355843,  0.2859006 , -0.08498826], dtype=float64)}
# PSF Params: {'scale_factor': 1, 'offset': 1}
# Misc Params: {'distance': 72.78, 'pxInArcsec': 0.01414, 'nx': 180, 'ny': 180, 'halfNbSlices': 25, 'flux_scaling': Array(58985.77197882, dtype=float64)}

# %%
##best model for HR 4796 has **9 knots**
HR4796_params = params1[0:13]
HR4796_knots = knots1
HR4796_angles = angles1

# %% [markdown]
# ## AU Mic

# %%
model1, params1, ll1, knots1, angles1 = gpi.init_fit('aumic_H_pol',num_knots=8,save=True)
# Out:
#          Current function value: 94596.045442
#          Iterations: 19
#          Function evaluations: 1485
#          Gradient evaluations: 67
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 94596.04544152907
#         x: [ 3.470e+00 -4.048e+00 ... -3.199e-01  1.313e+01]
#       nit: 19
#       jac: [-2.848e+00  7.285e-01 ...  1.328e+00  1.160e+00]
#  hess_inv: [[ 3.506e-01  1.551e-01 ...  1.756e-01  8.269e-02]
#             [ 1.551e-01  3.390e-01 ... -4.405e-01 -2.204e-01]
#             ...
#             [ 1.756e-01 -4.405e-01 ...  1.978e+00  4.214e-01]
#             [ 8.269e-02 -2.204e-01 ...  4.214e-01  1.378e+00]]
#      nfev: 1485
#      njev: 67
# Disk Params: {'accuracy': 0.005, 'alpha_in': 3.4703002958809988, 'alpha_out': -4.048385454386328, 'sma': 20.80416907256635, 'e': 0.42206355958115643, 'ksi0': -0.035094188973654336, 'gamma': 0.4690247700961444, 'beta': 3.2873624122042746, 'amin': 0.0, 'dens_at_r0': 1.0, 'inclination': 91.33296084041869, 'position_angle': 128.35567362895415, 'x_center': 92.3629422205142, 'y_center': 88.86947227498888, 'halfNbSlices': 25, 'omega': -1.6606935708402055}
# SPF Params: {'low_bound': Array(-0.99994517, dtype=float64), 'up_bound': Array(0.99994517, dtype=float64), 'num_knots': 8, 'knot_values': Array([-38.4542218 ,   6.93604067, -16.74872523,  -0.92656899,
#         -2.72991315,  -6.39022586,   0.39544381, -16.23246255],      dtype=float64)}
# PSF Params: {'scale_factor': 1, 'offset': 1}
# Misc Params: {'distance': 9.72, 'pxInArcsec': 0.01414, 'nx': 180, 'ny': 180, 'halfNbSlices': 25, 'flux_scaling': Array(-3758.99847769, dtype=float64)}

# %%
##no detection! so no best model

# %% [markdown]
# ## HD 145560

# %%
model1, params1, ll1, knots1, angles1 = gpi.init_fit('hd145560_H_pol',num_knots=8,save=True)
# Out:
#          Current function value: 75549.870972
#          Iterations: 148
#          Function evaluations: 4554
#          Gradient evaluations: 207
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 75549.87097172801
#         x: [ 1.824e+01 -2.259e+00 ... -8.499e+02  2.114e+02]
#       nit: 148
#       jac: [ 1.514e-01  3.027e-01 ... -9.766e-04 -9.766e-04]
#  hess_inv: [[ 7.235e-02  5.683e-04 ... -1.251e+00  8.685e-01]
#             [ 5.683e-04  9.322e-04 ... -4.510e-02  4.713e-02]
#             ...
#             [-1.251e+00 -4.510e-02 ...  1.885e+02 -1.199e+02]
#             [ 8.685e-01  4.713e-02 ... -1.199e+02  8.579e+01]]
#      nfev: 4554
#      njev: 207
# Disk Params: {'accuracy': 0.005, 'alpha_in': 18.240963713849283, 'alpha_out': -2.258881573229245, 'sma': 58.05023481924442, 'e': -10.880830583184244, 'ksi0': -0.00012510589592342947, 'gamma': 0.8107727079499306, 'beta': 9.944618892023573, 'amin': 0.0, 'dens_at_r0': 1.0, 'inclination': 42.72336714629178, 'position_angle': 221.40568341685193, 'x_center': 93.89331054016176, 'y_center': 92.39656605810139, 'halfNbSlices': 25, 'omega': 2.292469592510488}
# SPF Params: {'low_bound': Array(-0.69340183, dtype=float64), 'up_bound': Array(0.69340183, dtype=float64), 'num_knots': 8, 'knot_values': Array([ 1.80199846,  1.56221404,  1.31077266,  1.22519188,  0.71971213,
#         0.42289031,  0.42155136, -0.10487575], dtype=float64)}
# PSF Params: {'scale_factor': 1, 'offset': 1}
# Misc Params: {'distance': 120.44, 'pxInArcsec': 0.01414, 'nx': 180, 'ny': 180, 'halfNbSlices': 25, 'flux_scaling': Array(4433055.45272339, dtype=float64)}

# %%
##best model for HD 145560 has **8 knots**
HD145560_params = params1[0:13]
HD145560_knots = knots1
HD145560_angles = angles1

# %% [markdown]
# ## HD 146897

# %%
model1, params1, ll1, knots1, angles1 = gpi.init_fit('hd146897_H_pol',num_knots=10,save=True)
# Out:
#          Current function value: 72727.186671
#          Iterations: 210
#          Function evaluations: 11867
#          Gradient evaluations: 494
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 72727.18667063181
#         x: [ 7.031e+00 -3.254e+00 ...  3.896e+00 -1.997e+01]
#       nit: 210
#       jac: [-4.268e-01  2.156e+01 ...  2.783e-01 -1.016e-01]
#  hess_inv: [[ 1.671e-02 -2.808e-04 ...  6.808e-03  1.546e-02]
#             [-2.808e-04  8.640e-03 ... -4.186e-02  1.223e-02]
#             ...
#             [ 6.808e-03 -4.186e-02 ...  3.940e-01 -2.439e-01]
#             [ 1.546e-02  1.223e-02 ... -2.439e-01  2.120e+00]]
#      nfev: 11867
#      njev: 494
# Disk Params: {'accuracy': 0.005, 'alpha_in': 7.0312068266199885, 'alpha_out': -3.2541565287307077, 'sma': 107.20548837405984, 'e': 0.15864797111337028, 'ksi0': 7.037420343141961, 'gamma': 1.9339338122820053, 'beta': 1.7267600872838675, 'amin': 0.0, 'dens_at_r0': 1.0, 'inclination': 89.54386592322265, 'position_angle': 294.54385856045394, 'x_center': 92.7027062884459, 'y_center': 90.73897922993285, 'halfNbSlices': 25, 'omega': -625.9010713830138}
# SPF Params: {'low_bound': Array(-0.9945219, dtype=float64), 'up_bound': Array(0.9945219, dtype=float64), 'num_knots': 10, 'knot_values': Array([-19.28691198,  -1.2308456 ,  -0.42404909,  -0.45995589,
#        -12.47103969,  13.53084343,  -2.86632756,  -1.97351652,
#         -2.46672819,  12.64527737], dtype=float64)}
# PSF Params: {'scale_factor': 1, 'offset': 1}
# Misc Params: {'distance': 131.5, 'pxInArcsec': 0.01414, 'nx': 180, 'ny': 180, 'halfNbSlices': 25, 'flux_scaling': Array(-709.2976791, dtype=float64)}

# %%
##best model for HD 145560 has **10 knots**
HD145560_params = params1[0:13]
HD145560_knots = knots1
HD145560_angles = angles1

# %% [markdown]
# ## CE Ant

# %%
model1, params1, ll1, knots1, angles1 = gpi.init_fit('ceant_H_pol',num_knots=6,save=True)

# %%
##no detection! so no best model
